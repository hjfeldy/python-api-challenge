# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_keys import g_key
# !jupyter nbextension enable --py gmaps
# Out:
# Enabling notebook extension jupyter-gmaps/extension...
#       - Validating: OK

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
df = pd.read_csv('../output_data/cities.csv')
del df['Unnamed: 0']
df
# Out:
#        Lat     Lon                City Country       Description   Temp  \
# 0    -3.42  114.85           martapura      id        few clouds  75.20
# 1   -34.48  -54.33               rocha      uy   overcast clouds  60.71
# 2    57.23   59.33        staroutkinsk      ru   overcast clouds   6.40
# 3   -54.80  -68.30             ushuaia      ar        light rain  44.60
# 4   -34.53   20.04          bredasdorp      za  scattered clouds  57.20
# ..     ...     ...                 ...     ...               ...    ...
# 561  42.80   93.45                hami      cn         clear sky  10.44
# 562  40.80 -124.16              eureka      us   overcast clouds  50.00
# 563 -45.87  -67.50  comodoro rivadavia      ar         clear sky  62.60
# 564  61.99  -49.67             paamiut      gl   overcast clouds  22.84
# 565  43.52 -114.32              hailey      us        light snow  23.00
#
#      Pressure  Humidity  Windspeed  Cloud Cover
# 0        1010        94       2.24           20
# 1        1011        79       6.85          100
# 2        1037        94       9.19           99
# 3         983        75      18.34           40
# 4        1011        87       3.36           46
# ..        ...       ...        ...          ...
# 561      1039        73       3.71            0
# 562      1019        94       1.99          100
# 563       999        36      25.28            0
# 564      1011        93      41.25          100
# 565      1019        92       2.95           90
#
# [566 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key = g_key)

locations = df[['Lat', 'Lon']]

fig = gmaps.figure()
layer = gmaps.heatmap_layer(locations, weights = df['Humidity'])
fig.add_layer(layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
# Our ideal hotel has temperature between 60 and 90 degrees, and relatively clear skies
hotel_df = df[(df['Temp'] > 70) & (df['Temp'] < 90) & (df['Cloud Cover'] < 50) & (df['Windspeed'] < 10) & (df['Humidity'] > 60)]
hotel_df
# Out:
#        Lat     Lon               City Country       Description   Temp  \
# 0    -3.42  114.85          martapura      id        few clouds  75.20
# 8    18.42  -64.62          road town      vg  scattered clouds  78.80
# 28  -23.12 -134.97            rikitea      pf  scattered clouds  76.37
# 36    5.28  115.24             labuan      my        few clouds  80.60
# 44    7.77  -72.22      san cristobal      ve  scattered clouds  80.60
# 51   22.89 -109.91     cabo san lucas      mx         clear sky  73.99
# 71  -17.34  -39.22              prado      br         clear sky  75.15
# 85  -17.71  -39.25          caravelas      br         clear sky  74.07
# 86    5.26   -0.76            mumford      gh  scattered clouds  79.97
# 118  14.11  121.14        santo tomas      ph        few clouds  84.20
# 123  17.88  -76.41         morant bay      jm        few clouds  80.60
# 126   6.12   81.12         hambantota      lk        few clouds  71.60
# 132   5.41  100.34         georgetown      my        few clouds  78.80
# 160  -9.17  -36.22  santana do mundau      br  scattered clouds  77.00
# 164  -6.98  -34.83           cabedelo      br  scattered clouds  77.00
# 168  10.44   45.01            berbera      so         clear sky  75.04
# 171  16.86  -99.89           acapulco      mx  scattered clouds  82.40
# 173  13.22   80.32        kattivakkam      in              mist  75.20
# 184   7.90    4.32             ejigbo      ng         clear sky  72.39
# 195   1.55  110.33            kuching      my        few clouds  77.00
# 210 -22.96  -44.04        mangaratiba      br         clear sky  78.80
# 214   7.00   -9.47            gbarnga      lr  scattered clouds  71.06
# 220  -9.43  159.95            honiara      sb       shower rain  86.00
# 222   6.30  -10.80           monrovia      lr        few clouds  77.00
# 230  16.25  103.07       kosum phisai      th        few clouds  78.01
# 242  -6.41  -48.54            xambioa      br  scattered clouds  77.83
# 271  11.00  122.67             dingle      ph  scattered clouds  80.02
# 272  25.99  -80.23            miramar      us         clear sky  75.20
# 280  -5.20  -35.46             touros      br        few clouds  78.80
# 285  21.88  -79.84            condado      cu  scattered clouds  77.00
# 290 -16.16   33.59               tete      mz  scattered clouds  77.00
# 305  -8.84   13.23             luanda      ao        few clouds  73.40
# 322 -15.89  -52.26    barra do garcas      br  scattered clouds  76.55
# 329 -13.20   49.05           ambilobe      mg  scattered clouds  74.19
# 331 -19.90   48.80           mahanoro      mg        light rain  72.37
# 334   8.13   -5.10            katiola      ci         clear sky  75.20
# 336  -6.13   12.37               soyo      ao  scattered clouds  76.87
# 342  -0.72    8.78        port-gentil      ga  scattered clouds  80.60
# 384 -20.47   22.72           sehithwa      bw        few clouds  76.39
# 390  10.57   72.64          kavaratti      in        few clouds  81.75
# 391  14.31  121.11         santa rosa      ph        few clouds  84.20
# 394  18.20  -73.75          les cayes      ht        few clouds  75.81
# 395   6.58    3.75              lagos      ng         clear sky  78.01
# 396   5.79    0.90             anloga      gh  scattered clouds  80.60
# 410  -4.88  -66.90           carauari      br  scattered clouds  76.73
# 412 -10.17  123.58             kupang      id  scattered clouds  80.60
# 435  14.64  102.79          nang rong      th        few clouds  80.01
# 451   9.97   98.63             ranong      th        few clouds  73.40
# 466  18.63  -91.83             carmen      mx        few clouds  82.40
# 474  18.70  -95.50        mundo nuevo      mx         clear sky  74.08
# 479  -9.60  -35.96              pilar      br  scattered clouds  78.80
# 482  11.28  -15.83            bubaque      gw        few clouds  80.42
# 485   6.70  101.62           sai buri      th  scattered clouds  75.20
# 495   9.54  -13.68            conakry      gn         clear sky  81.55
# 497   6.73   -3.50         abengourou      ci  scattered clouds  72.16
# 512  -4.14   39.32            kinango      ke        few clouds  77.00
# 526 -14.90   50.28           antalaha      mg  scattered clouds  73.85
# 537   5.38  -52.95          sinnamary      gf         clear sky  78.03
# 551   5.48  -53.20           iracoubo      gf         clear sky  78.57
#
#      Pressure  Humidity  Windspeed  Cloud Cover
# 0        1010        94       2.24           20
# 8        1017        83       6.93           40
# 28       1015        68       5.70           39
# 36       1010        88       1.12           20
# 44       1013        69       6.93           40
# 51       1016        64       8.05            5
# 71       1016        84       7.25            1
# 85       1016        85       5.97            0
# 86       1011        83       8.88           27
# 118      1011        70       7.23           20
# 123      1015        78       3.36           20
# 126      1009       100       3.36           20
# 132      1008        94       4.88           20
# 160      1016        83       5.82           40
# 164      1015        94       4.70           40
# 168      1015        62       5.95            0
# 171      1011        78       2.24           40
# 173      1011        94       2.24           20
# 184      1010        96       4.05            1
# 195      1010        94       2.24           20
# 210      1012        78       6.93            0
# 214      1012        97       1.50           42
# 220      1007        74       5.82           40
# 222      1011        94       5.19           20
# 230      1012        83       6.93           20
# 242      1011        76       2.48           36
# 271      1010        86       7.52           32
# 272      1019        73       4.70            1
# 280      1014        83       6.93           20
# 285      1016        73       2.24           36
# 290      1012        83       4.70           40
# 305      1009        88       3.36           20
# 322      1013        68       0.58           49
# 329      1011        86       2.30           35
# 331      1016        84       5.19           37
# 334      1014        94       6.93            0
# 336      1010        80       6.33           38
# 342      1011        88       8.05           40
# 384      1008        61       6.91           16
# 390      1009        66       2.59           23
# 391      1011        70       9.84           20
# 394      1015        80       3.76           21
# 395      1010        91       4.23            0
# 396      1011        88       3.36           40
# 410      1009        84       1.83           47
# 412      1009        88       3.36           40
# 435      1011       100       2.06           20
# 451      1009       100       3.51           20
# 466      1012        74       8.05           20
# 474      1011        86       9.22            0
# 479      1016        78       6.93           40
# 482      1011        62       7.99           15
# 485      1009        94       6.93           40
# 495      1011        77       6.85            1
# 497      1011        98       2.68           27
# 512      1011        94       2.24           20
# 526      1012        81       8.66           25
# 537      1013        85       8.08            5
# 551      1013        84       8.70           10

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotels = []
for row in hotel_df.iterrows():
    lat = row[1]['Lat']
    lon = row[1]['Lon']
    url = f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lon}&key={g_key}&radius=5000&keyword=hotel'
    res = requests.get(url)
    j = res.json()
    
    if j['status'] == 'ZERO_RESULTS':
        hotels.append('--')
        continue
    hotels.append(j['results'][0]['name'])
hotel_df['Hotel Name'] = hotels
# Out:
# <ipython-input-5-c2a7286e8330>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df['Hotel Name'] = hotels

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lon"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(markers)


# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
hotel_df
# Out:
#        Lat     Lon               City Country       Description   Temp  \
# 0    -3.42  114.85          martapura      id        few clouds  75.20
# 8    18.42  -64.62          road town      vg  scattered clouds  78.80
# 28  -23.12 -134.97            rikitea      pf  scattered clouds  76.37
# 36    5.28  115.24             labuan      my        few clouds  80.60
# 44    7.77  -72.22      san cristobal      ve  scattered clouds  80.60
# 51   22.89 -109.91     cabo san lucas      mx         clear sky  73.99
# 71  -17.34  -39.22              prado      br         clear sky  75.15
# 85  -17.71  -39.25          caravelas      br         clear sky  74.07
# 86    5.26   -0.76            mumford      gh  scattered clouds  79.97
# 118  14.11  121.14        santo tomas      ph        few clouds  84.20
# 123  17.88  -76.41         morant bay      jm        few clouds  80.60
# 126   6.12   81.12         hambantota      lk        few clouds  71.60
# 132   5.41  100.34         georgetown      my        few clouds  78.80
# 160  -9.17  -36.22  santana do mundau      br  scattered clouds  77.00
# 164  -6.98  -34.83           cabedelo      br  scattered clouds  77.00
# 168  10.44   45.01            berbera      so         clear sky  75.04
# 171  16.86  -99.89           acapulco      mx  scattered clouds  82.40
# 173  13.22   80.32        kattivakkam      in              mist  75.20
# 184   7.90    4.32             ejigbo      ng         clear sky  72.39
# 195   1.55  110.33            kuching      my        few clouds  77.00
# 210 -22.96  -44.04        mangaratiba      br         clear sky  78.80
# 214   7.00   -9.47            gbarnga      lr  scattered clouds  71.06
# 220  -9.43  159.95            honiara      sb       shower rain  86.00
# 222   6.30  -10.80           monrovia      lr        few clouds  77.00
# 230  16.25  103.07       kosum phisai      th        few clouds  78.01
# 242  -6.41  -48.54            xambioa      br  scattered clouds  77.83
# 271  11.00  122.67             dingle      ph  scattered clouds  80.02
# 272  25.99  -80.23            miramar      us         clear sky  75.20
# 280  -5.20  -35.46             touros      br        few clouds  78.80
# 285  21.88  -79.84            condado      cu  scattered clouds  77.00
# 290 -16.16   33.59               tete      mz  scattered clouds  77.00
# 305  -8.84   13.23             luanda      ao        few clouds  73.40
# 322 -15.89  -52.26    barra do garcas      br  scattered clouds  76.55
# 329 -13.20   49.05           ambilobe      mg  scattered clouds  74.19
# 331 -19.90   48.80           mahanoro      mg        light rain  72.37
# 334   8.13   -5.10            katiola      ci         clear sky  75.20
# 336  -6.13   12.37               soyo      ao  scattered clouds  76.87
# 342  -0.72    8.78        port-gentil      ga  scattered clouds  80.60
# 384 -20.47   22.72           sehithwa      bw        few clouds  76.39
# 390  10.57   72.64          kavaratti      in        few clouds  81.75
# 391  14.31  121.11         santa rosa      ph        few clouds  84.20
# 394  18.20  -73.75          les cayes      ht        few clouds  75.81
# 395   6.58    3.75              lagos      ng         clear sky  78.01
# 396   5.79    0.90             anloga      gh  scattered clouds  80.60
# 410  -4.88  -66.90           carauari      br  scattered clouds  76.73
# 412 -10.17  123.58             kupang      id  scattered clouds  80.60
# 435  14.64  102.79          nang rong      th        few clouds  80.01
# 451   9.97   98.63             ranong      th        few clouds  73.40
# 466  18.63  -91.83             carmen      mx        few clouds  82.40
# 474  18.70  -95.50        mundo nuevo      mx         clear sky  74.08
# 479  -9.60  -35.96              pilar      br  scattered clouds  78.80
# 482  11.28  -15.83            bubaque      gw        few clouds  80.42
# 485   6.70  101.62           sai buri      th  scattered clouds  75.20
# 495   9.54  -13.68            conakry      gn         clear sky  81.55
# 497   6.73   -3.50         abengourou      ci  scattered clouds  72.16
# 512  -4.14   39.32            kinango      ke        few clouds  77.00
# 526 -14.90   50.28           antalaha      mg  scattered clouds  73.85
# 537   5.38  -52.95          sinnamary      gf         clear sky  78.03
# 551   5.48  -53.20           iracoubo      gf         clear sky  78.57
#
#      Pressure  Humidity  Windspeed  Cloud Cover  \
# 0        1010        94       2.24           20
# 8        1017        83       6.93           40
# 28       1015        68       5.70           39
# 36       1010        88       1.12           20
# 44       1013        69       6.93           40
# 51       1016        64       8.05            5
# 71       1016        84       7.25            1
# 85       1016        85       5.97            0
# 86       1011        83       8.88           27
# 118      1011        70       7.23           20
# 123      1015        78       3.36           20
# 126      1009       100       3.36           20
# 132      1008        94       4.88           20
# 160      1016        83       5.82           40
# 164      1015        94       4.70           40
# 168      1015        62       5.95            0
# 171      1011        78       2.24           40
# 173      1011        94       2.24           20
# 184      1010        96       4.05            1
# 195      1010        94       2.24           20
# 210      1012        78       6.93            0
# 214      1012        97       1.50           42
# 220      1007        74       5.82           40
# 222      1011        94       5.19           20
# 230      1012        83       6.93           20
# 242      1011        76       2.48           36
# 271      1010        86       7.52           32
# 272      1019        73       4.70            1
# 280      1014        83       6.93           20
# 285      1016        73       2.24           36
# 290      1012        83       4.70           40
# 305      1009        88       3.36           20
# 322      1013        68       0.58           49
# 329      1011        86       2.30           35
# 331      1016        84       5.19           37
# 334      1014        94       6.93            0
# 336      1010        80       6.33           38
# 342      1011        88       8.05           40
# 384      1008        61       6.91           16
# 390      1009        66       2.59           23
# 391      1011        70       9.84           20
# 394      1015        80       3.76           21
# 395      1010        91       4.23            0
# 396      1011        88       3.36           40
# 410      1009        84       1.83           47
# 412      1009        88       3.36           40
# 435      1011       100       2.06           20
# 451      1009       100       3.51           20
# 466      1012        74       8.05           20
# 474      1011        86       9.22            0
# 479      1016        78       6.93           40
# 482      1011        62       7.99           15
# 485      1009        94       6.93           40
# 495      1011        77       6.85            1
# 497      1011        98       2.68           27
# 512      1011        94       2.24           20
# 526      1012        81       8.66           25
# 537      1013        85       8.08            5
# 551      1013        84       8.70           10
#
#                                         Hotel Name
# 0    Grand Dafam Q Hotel Banjarbaru || DHM Syariah
# 8         Wyndham Tortola BVI Lambert Beach Resort
# 28                         Pension Bianca & Benoit
# 36                              Hotel Labuan Point
# 44            Lidotel Hotel Boutique San Cristobal
# 51                             Hotel Mar de Cortez
# 71                                Cahy Praia Hotel
# 85                               Pousada Liberdade
# 86               Blue Diamond Beach and Spa Resort
# 118            Italy Condotel Darasa, Tanauan City
# 123                  Whispering Bamboo Cove Resort
# 126             The Peacock Beach Hotel Hambantota
# 132                      The Prestige Hotel Penang
# 160                                             --
# 164                                  Hotel Almagre
# 168                                    Damal Hotel
# 171                         Hotel Emporio Acapulco
# 173                                THE CHIRAAG INN
# 184              Palm Hotel And Recreation Limited
# 195                         Imperial Hotel Kuching
# 210                     Portobello Resort & Safari
# 214                                Passion Hotel 1
# 220                            Heritage Park Hotel
# 222                          The Royal Grand Hotel
# 230                                         Banrao
# 242                             Hotel Rio Araguaia
# 271                                             --
# 272                                 May-Dee Suites
# 280                         Hotel Vila Gale Touros
# 285                                             --
# 290                              Baobab Hotel Tete
# 305                               EPIC SANA Luanda
# 322                                   Hilton Hotel
# 329                                 Hotel National
# 331                           Bungalow le Prestige
# 334                                   Hotel Hambol
# 336                                 Hotel Nempanzu
# 342                                  Hotel du Parc
# 384                             MONLEK GUEST HOUSE
# 390                                     yaad Hotal
# 391                   El Cielito Hotel - Sta. Rosa
# 394                                   Villa Orphee
# 395                                             --
# 396                           Bulls and Anchor Inn
# 410                                Tatiana's Hotel
# 412         ASTON Kupang Hotel & Convention Center
# 435                   Socool Grand Hotel Nang Rong
# 451                                     Sook Hotel
# 466          HOTEL PLAZA MIRADOR Ciudad Del Carmen
# 474                                             --
# 479                                             --
# 482                                  Ponta Anchaca
# 485                                             --
# 495                             Noom Hotel Conakry
# 497                                   hotel newman
# 512                                             --
# 526                                   Villa-Malaza
# 537                            L'oiseau de Paradis
# 551                             Le Gite D Iracoubo
